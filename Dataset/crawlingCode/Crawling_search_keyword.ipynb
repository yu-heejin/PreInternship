# %%
import threading
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import urllib.request

# %%
# 드라이버 = 구글 드라이버 위치
driver = webdriver.Chrome('C:\ProgramData\Anaconda3\Lib\site-packages\selenium\webdriver\chrome\chromedriver.exe')
# 드라이버로 열 웹페이지(구글 이미지)
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
# 구글 이미지의 검색창(F12->html)name='q')
elem = driver.find_element_by_name("q")
# 검색할 키워드 검색창에 입력
elem.send_keys("Ghibli Profile Image")
# enter키 전송 = 검색
elem.send_keys(Keys.RETURN)

# 스크롤 내리기
SCROLL_PAUSE_TIME = 1.0

# Get scroll height ; 브라우저 높이
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom ; 브라우저 끝까지 스크롤을 내리겠다
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height ; 이번 높이 = 브라우저 높이 ; 끝까지 내려옴
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
#         끝까지 내려왔으면 '결과더보기(html-class='mye4qd')' 누르기 ".mye4qd" or ".r0zKGf"
        try:
            driver.find_element_by_css_selector(".r0zKGf").click()
        except:
            break
    last_height = new_height
    
# import datetime

# def doScrollDown(whileSeconds):
#     start = datetime.datetime.now()
#     end = start + datetime.timedelta(seconds=whileSeconds)
#     while True:
#         driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
#         time.sleep(1)
#         if new_height == last_height:
# #         끝까지 내려왔으면 '결과더보기(html-class='mye4qd')' 누르기 ".mye4qd" or ".r0zKGf"
#             try:
#                 driver.find_element_by_css_selector(".mye4qd" or ".r0zKGf").click()
#             except:
#                 break
#         if datetime.datetime.now() > end:
#             break
        
# doScrollDown(60)

#이미지
images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
#이미지 개수 변수
count = 1

# 반복문~ 작은 이미지를 클릭해 원본 이미지 나오고 링크가서 다운로드
for image in images:
#     try-except 안 되는 거 있으면 그냥 넘기고 다음 이미지로 가라
    try:
        #이미지 클릭
        image.click()
        # 이미지 로딩..
        time.sleep(3)
        # 1. 원본 이미지 태그(n3VNCb)를 활용해 이미지url(src)로 들어가기
#         imgUrl = driver.find_element_by_css_selector(".n3VNCb").get_attribute('src')
        # 2. 원본 이미지 XPath(n3VNCb)를 활용해 이미지url(src)로 들어가기
        imgUrl = driver.find_element_by_xpath("/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div/a/img").get_attribute('src')
        # url에서 이미지 다운로드
        print(urllib.request.urlretrieve(imgUrl,"profileimage_" + str(count) + ".jpg"))
        count = count + 1
    except:
        pass
    
driver.close()
# Out:
# ('profileimage_1.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_2.jpg', <http.client.HTTPMessage object at 0x000002827D85D048>)
# ('profileimage_3.jpg', <email.message.Message object at 0x000002827D866D88>)
# ('profileimage_4.jpg', <email.message.Message object at 0x000002827D931488>)
# ('profileimage_5.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_6.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_7.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_8.jpg', <email.message.Message object at 0x000002827D97E108>)
# ('profileimage_9.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_10.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_11.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_12.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_13.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_14.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_15.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_16.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_17.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_18.jpg', <email.message.Message object at 0x000002827D931508>)
# ('profileimage_19.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_20.jpg', <http.client.HTTPMessage object at 0x000002827D8B3048>)
# ('profileimage_21.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_22.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_23.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_24.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_25.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_26.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_27.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_28.jpg', <http.client.HTTPMessage object at 0x000002827D8D1148>)
# ('profileimage_29.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_30.jpg', <http.client.HTTPMessage object at 0x000002827D8DC0C8>)
# ('profileimage_31.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_32.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_33.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_34.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_35.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_36.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_37.jpg', <http.client.HTTPMessage object at 0x000002827D8BE0C8>)
# ('profileimage_38.jpg', <http.client.HTTPMessage object at 0x000002827D8D1048>)
# ('profileimage_39.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_40.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_41.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_42.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_43.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_44.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_45.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_46.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_47.jpg', <http.client.HTTPMessage object at 0x000002827D935FC8>)
# ('profileimage_48.jpg', <http.client.HTTPMessage object at 0x000002827D90AC88>)
# ('profileimage_49.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_50.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_51.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_52.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_53.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_54.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_55.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_56.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_57.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_58.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_59.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_60.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_61.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_62.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_63.jpg', <http.client.HTTPMessage object at 0x000002827D8C4188>)
# ('profileimage_64.jpg', <http.client.HTTPMessage object at 0x000002827D931508>)
# ('profileimage_65.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_66.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_67.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_68.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_69.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_70.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_71.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_72.jpg', <http.client.HTTPMessage object at 0x000002827D8EA188>)
# ('profileimage_73.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_74.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_75.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_76.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_77.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_78.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_79.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_80.jpg', <http.client.HTTPMessage object at 0x000002827D90AD08>)
# ('profileimage_81.jpg', <http.client.HTTPMessage object at 0x000002827D8D70C8>)
# ('profileimage_82.jpg', <http.client.HTTPMessage object at 0x000002827D90AFC8>)
# ('profileimage_83.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_84.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_85.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_86.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_87.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_88.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_89.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_90.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_91.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_92.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_93.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_94.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_95.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_96.jpg', <http.client.HTTPMessage object at 0x000002827D8B3088>)
# ('profileimage_97.jpg', <http.client.HTTPMessage object at 0x000002827D8D1148>)
# ('profileimage_98.jpg', <email.message.Message object at 0x000002827D90AD08>)
# ('profileimage_99.jpg', <email.message.Message object at 0x000002827D931488>)
# ('profileimage_100.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_101.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_102.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_103.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_104.jpg', <email.message.Message object at 0x000002827D934B48>)
# ('profileimage_105.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_106.jpg', <http.client.HTTPMessage object at 0x000002827D8C4108>)
# ('profileimage_107.jpg', <http.client.HTTPMessage object at 0x000002827D8D7048>)
# ('profileimage_108.jpg', <http.client.HTTPMessage object at 0x000002827D931688>)
# ('profileimage_109.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_110.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_111.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_112.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_113.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_114.jpg', <email.message.Message object at 0x000002827D97E048>)
# ('profileimage_115.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_116.jpg', <http.client.HTTPMessage object at 0x000002827D8D7088>)
# ('profileimage_117.jpg', <http.client.HTTPMessage object at 0x000002827D931488>)
# ('profileimage_118.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_119.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_120.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_121.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_122.jpg', <http.client.HTTPMessage object at 0x000002827D90AC08>)
# ('profileimage_123.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_124.jpg', <http.client.HTTPMessage object at 0x000002827D8B3048>)
# ('profileimage_125.jpg', <http.client.HTTPMessage object at 0x000002827D8D1048>)
# ('profileimage_126.jpg', <http.client.HTTPMessage object at 0x000002827D835B88>)
# ('profileimage_127.jpg', <http.client.HTTPMessage object at 0x000002827D8610C8>)
# ('profileimage_128.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_129.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_130.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_131.jpg', <http.client.HTTPMessage object at 0x000002827D90AC88>)
# ('profileimage_132.jpg', <http.client.HTTPMessage object at 0x000002827D8D7048>)
# ('profileimage_133.jpg', <http.client.HTTPMessage object at 0x000002827D8B3108>)
# ('profileimage_134.jpg', <http.client.HTTPMessage object at 0x000002827D931B08>)
# ('profileimage_135.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_136.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_137.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_138.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_139.jpg', <http.client.HTTPMessage object at 0x000002827D90AFC8>)
# ('profileimage_140.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_141.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_142.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_143.jpg', <http.client.HTTPMessage object at 0x000002827D934C48>)
# ('profileimage_144.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_145.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_146.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_147.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_148.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_149.jpg', <http.client.HTTPMessage object at 0x000002827D90AC88>)
# ('profileimage_150.jpg', <http.client.HTTPMessage object at 0x000002827D8D7088>)
# ('profileimage_151.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_152.jpg', <http.client.HTTPMessage object at 0x000002827D861188>)
# ('profileimage_153.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_154.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_155.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_156.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_157.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_158.jpg', <http.client.HTTPMessage object at 0x000002827D90AC08>)
# ('profileimage_159.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_160.jpg', <http.client.HTTPMessage object at 0x000002827D931488>)
# ('profileimage_161.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_162.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_163.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_164.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_165.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_166.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_167.jpg', <http.client.HTTPMessage object at 0x000002827D8BE0C8>)
# ('profileimage_168.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_169.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_170.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_171.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_172.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_173.jpg', <http.client.HTTPMessage object at 0x000002827D90AC08>)
# ('profileimage_174.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_175.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_176.jpg', <http.client.HTTPMessage object at 0x000002827D8C4048>)
# ('profileimage_177.jpg', <http.client.HTTPMessage object at 0x000002827D8D7048>)
# ('profileimage_178.jpg', <http.client.HTTPMessage object at 0x000002827D97E048>)
# ('profileimage_179.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_180.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_181.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_182.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_183.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_184.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_185.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_186.jpg', <http.client.HTTPMessage object at 0x000002827D8BE048>)
# ('profileimage_187.jpg', <http.client.HTTPMessage object at 0x000002827D8616C8>)
# ('profileimage_188.jpg', <http.client.HTTPMessage object at 0x000002827D90AFC8>)
# ('profileimage_189.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_190.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_191.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_192.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_193.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_194.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_195.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_196.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_197.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_198.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_199.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_200.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_201.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_202.jpg', <http.client.HTTPMessage object at 0x000002827D934F08>)
# ('profileimage_203.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_204.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_205.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_206.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_207.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_208.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_209.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_210.jpg', <http.client.HTTPMessage object at 0x000002827D8EA0C8>)
# ('profileimage_211.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_212.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_213.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_214.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_215.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_216.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_217.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_218.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_219.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_220.jpg', <http.client.HTTPMessage object at 0x000002827D861588>)
# ('profileimage_221.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_222.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_223.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_224.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_225.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_226.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_227.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_228.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_229.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_230.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_231.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_232.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_233.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_234.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_235.jpg', <http.client.HTTPMessage object at 0x000002827D934DC8>)
# ('profileimage_236.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_237.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_238.jpg', <http.client.HTTPMessage object at 0x000002827D90A9C8>)
# ('profileimage_239.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_240.jpg', <http.client.HTTPMessage object at 0x000002827D90AC08>)
# ('profileimage_241.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_242.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_243.jpg', <http.client.HTTPMessage object at 0x000002827D855208>)
# ('profileimage_244.jpg', <http.client.HTTPMessage object at 0x000002827D90ABC8>)
# ('profileimage_245.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_246.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_247.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_248.jpg', <http.client.HTTPMessage object at 0x000002827D8D1148>)
# ('profileimage_249.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_250.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_251.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_252.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_253.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_254.jpg', <http.client.HTTPMessage object at 0x000002827D8C4088>)
# ('profileimage_255.jpg', <http.client.HTTPMessage object at 0x000002827D90A8C8>)
# ('profileimage_256.jpg', <http.client.HTTPMessage object at 0x000002827D8C4148>)
# ('profileimage_257.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_258.jpg', <http.client.HTTPMessage object at 0x000002827D90AE48>)
# ('profileimage_259.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_260.jpg', <http.client.HTTPMessage object at 0x000002827D90AE88>)
# ('profileimage_261.jpg', <http.client.HTTPMessage object at 0x000002827D90AB88>)
# ('profileimage_262.jpg', <http.client.HTTPMessage object at 0x000002827D8D11C8>)
# ('profileimage_263.jpg', <http.client.HTTPMessage object at 0x000002827D8BE108>)
# ('profileimage_264.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_265.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_266.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_267.jpg', <http.client.HTTPMessage object at 0x000002827D90AD48>)
# ('profileimage_268.jpg', <http.client.HTTPMessage object at 0x000002827D90AC08>)
# ('profileimage_269.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_270.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_271.jpg', <http.client.HTTPMessage object at 0x000002827D8D1048>)
# ('profileimage_272.jpg', <http.client.HTTPMessage object at 0x000002827D90AEC8>)
# ('profileimage_273.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_274.jpg', <http.client.HTTPMessage object at 0x000002827D90AC88>)
# ('profileimage_275.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_276.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_277.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_278.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)
# ('profileimage_279.jpg', <http.client.HTTPMessage object at 0x000002827D8BE048>)
# ('profileimage_280.jpg', <http.client.HTTPMessage object at 0x000002827D934D08>)
# ('profileimage_281.jpg', <http.client.HTTPMessage object at 0x000002827D90ADC8>)
# ('profileimage_282.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_283.jpg', <http.client.HTTPMessage object at 0x000002827D90AB48>)
# ('profileimage_284.jpg', <http.client.HTTPMessage object at 0x000002827D90AF08>)
# ('profileimage_285.jpg', <http.client.HTTPMessage object at 0x000002827D90AB08>)
# ('profileimage_286.jpg', <http.client.HTTPMessage object at 0x000002827D90AA08>)
# ('profileimage_287.jpg', <http.client.HTTPMessage object at 0x000002827D90ACC8>)
# ('profileimage_288.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_289.jpg', <http.client.HTTPMessage object at 0x000002827D861448>)
# ('profileimage_290.jpg', <http.client.HTTPMessage object at 0x000002827D90AD88>)
# ('profileimage_291.jpg', <http.client.HTTPMessage object at 0x000002827D90AF88>)
# ('profileimage_292.jpg', <http.client.HTTPMessage object at 0x000002827D90AFC8>)
# ('profileimage_293.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_294.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_295.jpg', <http.client.HTTPMessage object at 0x000002827D90AAC8>)
# ('profileimage_296.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_297.jpg', <http.client.HTTPMessage object at 0x000002827D90AA48>)
# ('profileimage_298.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_299.jpg', <http.client.HTTPMessage object at 0x000002827D90AA88>)
# ('profileimage_300.jpg', <http.client.HTTPMessage object at 0x000002827D90A948>)
# ('profileimage_301.jpg', <http.client.HTTPMessage object at 0x000002827D90A988>)
# ('profileimage_302.jpg', <http.client.HTTPMessage object at 0x000002827D90AF48>)
# ('profileimage_303.jpg', <http.client.HTTPMessage object at 0x000002827D90AC48>)
# ('profileimage_304.jpg', <http.client.HTTPMessage object at 0x000002827D90A908>)
# ('profileimage_305.jpg', <http.client.HTTPMessage object at 0x000002827D90AE08>)

# %%
# <<<<<<<<<<TEST>>>>>>>>>>
# 드라이버 = 구글 드라이버 위치
driver = webdriver.Chrome('C:\ProgramData\Anaconda3\Lib\site-packages\selenium\webdriver\chrome\chromedriver.exe')
# 드라이버로 열 웹페이지(구글 이미지)
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
# 구글 이미지의 검색창(F12->html)name='q')
elem = driver.find_element_by_name("q")
# 검색할 키워드 검색창에 입력
elem.send_keys("Ghibli Profile Image")
# enter키 전송 = 검색
elem.send_keys(Keys.RETURN)

#이미지
images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")[1].click()
# 이미지 로딩..
time.sleep(3)
# 원본 이미지 태그(n3VNCb)를 활용해 이미지url(src)로 들어가기
imgUrl = driver.find_element_by_xpath("/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div/a/img").get_attribute('src')
# url에서 이미지 다운로드
print(urllib.request.urlretrieve(imgUrl,"test_xpath.jpg"))
# Out:
# ('test_xpath.jpg', <http.client.HTTPMessage object at 0x000001F48BCE4B48>)

# %%
image_count = len(browser.find_elements_by_tag_name("img"))

#     print("로드된 이미지 개수 : ", image_count)

driver.implicitly_wait(2)
driver.set_window_size(500, 500)

#    이미지 다운로드 받을 폴더
for i in range( search_limit ) :
    image = browser.find_elements_by_tag_name("img")[i]
    image.screenshot('‪C:/Users/kcc/0126Ghibli_img_download' + str(i) + ".png")

browser.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8480/657408879.py in <module>
#       1 #IC2
#       2
# ----> 3 search_url = "https://www.google.com/search?q=" + str(search_name) + "&hl=ko&tbm=isch"
#       4
#       5 driver = webdriver.Chrome('C:\ProgramData\Anaconda3\Lib\site-packages\selenium\webdriver\chrome\chromedriver.exe')
#
# NameError: name 'search_name' is not defined

# %%
#IC4 - 3. 검색어 입력하기
search = "Ghibli profile picture"
elem = driver.find_element_by_name("q")
elem.send_keys(search)
elem.send_keys(Keys.RETURN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8480/2905652441.py in <module>
#       1 #IC4 - 3. 검색어 입력하기
#       2 search = "Ghibli profile picture"
# ----> 3 elem = driver.find_element_by_name("q")
#       4 elem.send_keys(search)
#       5 elem.send_keys(Keys.RETURN)
#
# NameError: name 'driver' is not defined

# %%
# IC4 - 4. 스크롤 끝까지 내리기
SCROLL_PAUSE_TIME = 1

last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

# %%
# IC4 - 5. 이미지 찾아서 원본 파일로 저장하기
images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
count = 1

for image in images:
    try:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element_by_xpath("//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div/a/img").get_attribute('src')
#         imgUrl = driver.find_element_by_xpath('Sva75c').get_attribute('src')
        urllib.request.urlretrieve(imgUrl, "GHIBLI2/" + search + "_" + str(count) + ".jpg")
        print("Image saved: GHIBLI2_{}.jpg".format(count))
        count += 1
    except:
        pass

driver.close()
